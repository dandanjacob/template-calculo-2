# %%
# Definir uma função
f(x) = sin(x) + 0.5*x

# Criar o gráfico no intervalo [-5, 5]
plot1 = plot(f, (x, -5, 5), color='blue', thickness=2, legend_label='f(x) = sin(x) + 0.5x')

# Adicionar título e rótulos
plot1.axes_labels(['x', 'f(x)'])
plot1.show()
# Out:
# Graphics object consisting of 1 graphics primitive
